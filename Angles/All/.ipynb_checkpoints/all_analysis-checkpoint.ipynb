# %%
def remove_outlier(flux, err):
    q1, q3 = np.percentile(flux, [25,75])
    iqr = q3 - q1
    
    lower_bound = q1 - (1.5 * iqr) 
    upper_bound = q3 + (1.5 * iqr)
    
    for count, f in enumerate(flux):
        if f < lower_bound or f > upper_bound:
            flux.remove(f)
            err.pop(count)

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
from datetime import datetime
from matplotlib.offsetbox import AnchoredText
# %matplotlib inline

#open flux csv file and read in data 
file = open('0_angle_data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_0 = []
for r in rows:
    flux_0.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_0 = []
for e in rows:
    error_0.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_0)
plt.errorbar(good_times, flux_0, yerr=error_0, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('15_angle_data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_15 = []
for r in rows:
    flux_15.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_15 = []
for e in rows:
    error_15.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_15)
plt.errorbar(good_times, flux_15, yerr=error_15, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('30_angle_data_fix.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_30 = []
for r in rows:
    flux_30.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_30 = []
for e in rows:
    error_30.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_30)
plt.errorbar(good_times, flux_30, yerr=error_30, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('45_angle_data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_45 = []
for r in rows:
    flux_45.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_45 = []
for e in rows:
    error_45.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_45)
plt.errorbar(good_times, flux_45, yerr=error_45, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
from datetime import datetime
from matplotlib.offsetbox import AnchoredText
# %matplotlib inline

#open flux csv file and read in data 
file = open('60_angle_data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_60 = []
for r in rows:
    flux_60.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_60 = []
for e in rows:
    error_60.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_60)
plt.errorbar(good_times, flux_60, yerr=error_60, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('75_angle_data_fix.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_75 = []
for r in rows:
    flux_75.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_75 = []
for e in rows:
    error_75.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_75)
plt.errorbar(good_times, flux_75, yerr=error_75, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('90_angle_data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_90 = []
for r in rows:
    flux_90.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_90 = []
for e in rows:
    error_90.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_90)
plt.errorbar(good_times, flux_90, yerr=error_90, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
#open flux csv file and read in data 
file = open('all_angles.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux_all = []
for r in rows:
    flux_all.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error_all = []
for e in rows:
    error_all.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux_all)
plt.errorbar(good_times, flux_all, yerr=error_all, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %%
remove_outlier(flux_all,error_all)

# %%
from scipy.optimize import curve_fit

angles =  []

z = 0
while z < len(flux_0):
    angles.append(0)
    z += 1
f = 0
while f < len(flux_15):
    angles.append(15)
    f += 1
t = 0
while t < len(flux_30):
    angles.append(30)
    t += 1
fo = 0
while fo < len(flux_45):
    angles.append(45)
    fo += 1
s = 0
while s < len(flux_60):
    angles.append(60)
    s += 1
se = 0
while se < len(flux_75):
    angles.append(75)
    se += 1
ni = 0
while ni < len(flux_90):
    angles.append(90)
    ni += 1

rad_angles = [a * (np.pi / 180) for a in angles]

def objective(angle, A, B, n):
    return A + B * (np.cos(angle)**(n)) 

popt, var = curve_fit(objective, rad_angles, flux_all, p0=[1208, 4266, 2], sigma = error_all, maxfev = 8000)

A, B, n = popt
print('A: %.5f B: %.5f n: %.5f' % (A, B, n))

#covariance matrix
#print(var)

#one std errors of parameters
perr = np.sqrt(np.diag(var))
print('std of n: ', perr[2])

d = (n - 2) / 2
print('percent error: ', d*100)

fit = objective(rad_angles, A, B, n)
ideal = objective(rad_angles, A, B, 2)

x = np.arange(0, 90, 0.1)
y_ideal = A + B * (np.cos(x * np.pi/180)**2)
y_fit = A + B * (np.cos(x * np.pi/180)**n)

plt.plot(x, y_fit, linestyle='dashed', label='n = %5.2f' %n)
plt.plot(x,y_ideal, c='r', label='n = 2')

plt.xlabel('Angle (deg)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.legend()
plt.show()
# Out:
# A: 1182.74643 B: 4369.64723 n: 2.51983
# std of n:  0.009735953671194912
# percent error:  25.991679781850195

# %%
angles =  [0, 15, 30, 45, 60, 75, 90]

remove_outlier(flux_0, error_0)
remove_outlier(flux_15, error_15)
remove_outlier(flux_30, error_30)
remove_outlier(flux_45, error_45)
remove_outlier(flux_60, error_60)
remove_outlier(flux_75, error_75)
remove_outlier(flux_90, error_90)

fluxs =  [flux_0, flux_15, flux_30, flux_45,  flux_60,  flux_75,  flux_90]
errs = [error_0, error_15, error_30, error_45, error_60, error_75, error_90]

for xe, ye, ee in zip(angles, fluxs, errs):
    plt.scatter([xe] * len(ye), ye)
    plt.errorbar([xe] * len(ye), ye, yerr=ee, fmt='o', capsize=4)

x = np.arange(0, 90, 0.1)
y_ideal = A + B * (np.cos(x * np.pi/180)**2)
y_fit = A + B * (np.cos(x * np.pi/180)**n)

plt.plot(x, y_fit, linestyle='dashed', label='n = %5.2f' %n)
plt.plot(x,y_ideal, c='r', label='n = 2')

plt.xlabel('Angle (deg)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.legend()
plt.show()

# %%
res0 = [(f - objective(0, A, B, n)) for f in flux_0]
res15 = [(f - objective(15*(np.pi/180), A, B, n)) for f in flux_15]
res30 = [(f - objective(30*(np.pi/180), A, B, n)) for f in flux_30]
res45 = [(f - objective(45*(np.pi/180), A, B, n)) for f in flux_45]
res60 = [(f - objective(60*(np.pi/180), A, B, n)) for f in flux_60]
res75 = [(f - objective(75*(np.pi/180), A, B, n)) for f in flux_75]
res90 = [(f - objective(90*(np.pi/180), A, B, n)) for f in flux_90]

ress = [res0, res15, res30, res45, res60, res75, res90]
means = [np.mean(r) for r in ress]
print(means)
mag_means = [abs(m) for m in means]

plt.scatter([0,15,30,45,60,75,90], mag_means)
plt.xlabel('Angle (deg)')
plt.ylabel('Residuals')
plt.show()
# Out:
# [63.01483662089434, -78.88192198925111, -59.506376577344085, 71.20444183074687, 1.3617077822820653, 51.17394301349425, -19.377823314341974]
