# %% [markdown]
# # Initial Calibration

# %% [markdown]
# ## Create scatter plot

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
from datetime import datetime
from matplotlib.offsetbox import AnchoredText
# %matplotlib inline

#open flux csv file and read in data 
file = open('initial_calibration.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux = []
for r in rows:
    flux.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error = []
for e in rows:
    error.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux)
plt.errorbar(good_times, flux, yerr=error, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %% [markdown]
# ## Create boxplot

# %%
plt.boxplot(flux)

plt.title('Flux Study')
plt.ylabel('Flux (events/m$^2$/min)')

plt.show()
plt.close()

# %% [markdown]
# ## Run statistical tests

# %%
import statistics as stats

print("Mean: ", stats.mean(flux))
print("Median: ", stats.median(flux))
print("Standard deviation: ", stats.stdev(flux))
print("Standard deviation of the mean: ", stats.stdev(flux) / np.sqrt(len(flux)))
print("Variance: ", stats.variance(flux))

err = 1 / np.sqrt(len(flux))
print("Percent statistical error: ", err * 100)
# Out:
# Mean:  3455.651765732103
# Median:  3608.418367
# Standard deviation:  628.1582404591068
# Standard deviation of the mean:  14.855432631433107
# Variance:  394582.77505668096
# Percent statistical error:  2.364918849202011

# %% [markdown]
# # Second Calibration

# %% [markdown]
# ## Scatter Plot

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
from datetime import datetime
from matplotlib.offsetbox import AnchoredText
# %matplotlib inline

#open flux csv file and read in data 
file = open('second_calibration.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
        rows.append(row)

#get flux from file
flux = []
for r in rows:
    flux.append(float(r[2]))

#get dates and times from  file
date_time = []
for d in rows:
    date_time.append(d[0] + ' ' + d[1])
good_times = pd.to_datetime(date_time, format='%y/%m/%d %H:%M:%S')

#get error in flux from file
error = []
for e in rows:
    error.append(float(e[3]))
    
#flux plot  
fig, ax = plt.subplots()
at = AnchoredText("Detector: 6709\n Channel Number:1", prop=dict(size=10), frameon=False, loc='upper right')
ax.add_artist(at)

plt.scatter(good_times, flux)
plt.errorbar(good_times, flux, yerr=error, fmt='o', capsize=4)
plt.title('Flux Study')
plt.xlabel('Time UTC (year-hour)')
plt.ylabel('Flux (events/m$^2$/min)')
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tick_params(bottom=True, top=True, left=True, right=True, direction='in')

plt.show()
plt.close

file.close()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(flux)

plt.title('Flux Study')
plt.ylabel('Flux (events/m$^2$/min)')

plt.show()
plt.close()

# %% [markdown]
# ## Statistical  Tests

# %%
import statistics as stats

print("Mean: ", stats.mean(flux))
print("Median: ", stats.median(flux))
print("Standard deviation: ", stats.stdev(flux))
print("Standard deviation of the mean: ", stats.stdev(flux) / np.sqrt(len(flux)))
print("Variance: ", stats.variance(flux))

err = 1 / np.sqrt(len(flux))
print("Percent statistical error: ", err * 100)
# Out:
# Mean:  5639.971172051649
# Median:  5637.755102
# Standard deviation:  166.23575033064242
# Standard deviation of the mean:  4.1468324622311865
# Variance:  27634.324687991677
# Percent statistical error:  2.494549129163341
